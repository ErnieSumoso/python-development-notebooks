# %%
import pandas as pd

df_genres = pd.read_csv("u.genre", sep='|', header=None, names=['genre', 'id'])
df_genres = df_genres[['id', 'genre']]
df_genres.tail()
# Out:
#     id     genre
# 14  14   Romance
# 15  15    Sci-Fi
# 16  16  Thriller
# 17  17       War
# 18  18   Western

# %%
data_columns = ['user_id', 'item_id', 'rating', 'timestamp']
df_data = pd.read_csv("u.data", sep='\t', header=None, names=data_columns)
df_data.tail()
# Out:
#        user_id  item_id  rating  timestamp
# 99995      880      476       3  880175444
# 99996      716      204       5  879795543
# 99997      276     1090       1  874795795
# 99998       13      225       2  882399156
# 99999       12      203       3  879959583

# %%
item_columns = \
[
    "movie id", "movie title", "release date", "video release date",
    "IMDb URL", "unknown", "Action", "Adventure",
    "Animation", "Children's", "Comedy", "Crime",
    "Documentary", "Drama", "Fantasy", "Film-Noir",
    "Horror", "Musical", "Mystery", "Romance",
    "Sci-Fi", "Thriller", "War", "Western"
]


df_items = pd.read_csv("u.item",
                       sep='|',
                       header=None,
                       names=item_columns,
                       encoding='latin-1')
df_items.tail()
# Out:
#       movie id                                movie title release date  \
# 1677      1678                          Mat' i syn (1997)  06-Feb-1998
# 1678      1679                           B. Monkey (1998)  06-Feb-1998
# 1679      1680                       Sliding Doors (1998)  01-Jan-1998
# 1680      1681                        You So Crazy (1994)  01-Jan-1994
# 1681      1682  Scream of Stone (Schrei aus Stein) (1991)  08-Mar-1996
#
#       video release date                                           IMDb URL  \
# 1677                 NaN  http://us.imdb.com/M/title-exact?Mat%27+i+syn+...
# 1678                 NaN  http://us.imdb.com/M/title-exact?B%2E+Monkey+(...
# 1679                 NaN      http://us.imdb.com/Title?Sliding+Doors+(1998)
# 1680                 NaN  http://us.imdb.com/M/title-exact?You%20So%20Cr...
# 1681                 NaN  http://us.imdb.com/M/title-exact?Schrei%20aus%...
#
#       unknown  Action  Adventure  Animation  Children's  ...  Fantasy  \
# ...
